# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikm-dev/ML_Projects/blob/main/student_grade_analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("/content/Student_Performance_Teaching_Effectiveness.csv")
X = df[['Study_Hours_per_Week']]
Y = df['Final_Grade']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
print("R2 score on test set:")
print(r2_score(Y_test, Y_pred))

#NEW INPUT
data = pd.DataFrame({
    'Study_Hours_per_Week': [9]
})
prediction = model.predict(data)
print("Prediction for a student studying 9 hours per week:")
print(prediction)
# Out:
# R2 score on test set:
# -0.00027325510042119916
# Prediction for a student studying 9 hours per week:
# [48.72614771]
